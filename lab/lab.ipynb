# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
feature_monomer = pickle.load(open("features_monomer.pkl","rb"))
feature_multimer = pickle.load(open("features_multimer.pkl","rb"))
result_monomer = pickle.load(open("result_model_1_ptm.pkl","rb"))
result_multimer = pickle.load(open("result_model_1_multimer.pkl","rb"))

# %%
feature_monomer.keys()
# Out:
# dict_keys(['aatype', 'between_segment_residues', 'domain_name', 'residue_index', 'seq_length', 'sequence', 'deletion_matrix_int', 'msa', 'num_alignments', 'msa_uniprot_accession_identifiers', 'msa_species_identifiers', 'template_aatype', 'template_all_atom_masks', 'template_all_atom_positions', 'template_domain_names', 'template_sequence', 'template_sum_probs'])

# %%
feature_multimer.keys()
# Out:
# dict_keys(['aatype', 'residue_index', 'seq_length', 'msa', 'num_alignments', 'template_aatype', 'template_all_atom_mask', 'template_all_atom_positions', 'asym_id', 'sym_id', 'entity_id', 'deletion_matrix', 'deletion_mean', 'all_atom_mask', 'all_atom_positions', 'assembly_num_chains', 'entity_mask', 'num_templates', 'cluster_bias_mask', 'bert_mask', 'seq_mask', 'msa_mask'])

# %%
result_monomer.keys()
# Out:
# dict_keys(['distogram', 'experimentally_resolved', 'masked_msa', 'predicted_aligned_error', 'predicted_lddt', 'structure_module', 'plddt', 'aligned_confidence_probs', 'max_predicted_aligned_error', 'ptm', 'ranking_confidence'])

# %%
result_multimer.keys()
# Out:
# dict_keys(['distogram', 'experimentally_resolved', 'masked_msa', 'predicted_aligned_error', 'predicted_lddt', 'structure_module', 'plddt', 'aligned_confidence_probs', 'max_predicted_aligned_error', 'ptm', 'iptm', 'ranking_confidence'])

# %%
plt.imshow(result_monomer["distogram"]["logits"][:,:,10])
plt.colorbar()

# %%
plt.imshow(result_monomer["experimentally_resolved"]["logits"])

# %%
plt.imshow(result_monomer["masked_msa"]["logits"][:,:,2])
